# %% [markdown]
# # SparkML Models Notebook

# %% [markdown]
# ## Imports

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when
from pyspark.ml.feature import VectorAssembler, StringIndexer, OneHotEncoder
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier, DecisionTreeClassifier
from pyspark.ml import Pipeline
from pyspark.sql.types import DoubleType
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %% [markdown]
# ## Spark Session Initialization

# %%
spark = SparkSession.builder \
    .appName("ProjectSuccessPrediction") \
    .config("spark.executor.memory", "24g") \
    .config("spark.driver.memory", "24g") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/20 20:41:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Loading the Data Using PySpark and General Preparation

# %%
# Load data
data = spark.read.csv("/kick_starter_cleaned.csv", header=True, inferSchema=True)

# Drop useless columns
columns_to_drop = ["category", "currency", "goal", "deadline", "launched", "pledged", "backers"]
data = data.drop(*columns_to_drop)

# Examine and transform the 'state' column to a binary label column
data = data.withColumn("label", when(col("state") == "successful", 1).otherwise(0))

# Drop rows where the state is 'live' as per the hint in the PDF
data = data.filter(col("state") != "live")

# Drop the 'state' column as it's now redundant
data = data.drop("state")

# %% [markdown]
# ## Grouping Categorical Columns and Encoding

# %%
# Columns to index and encode
categorical_columns = ["name", "main_category", "country"]

# Indexing and encoding pipelines
indexers = [StringIndexer(inputCol=col, outputCol=col+"_indexed") for col in categorical_columns]
encoders = [OneHotEncoder(inputCol=col+"_indexed", outputCol=col+"_encoded") for col in categorical_columns]

# Apply the indexers and encoders
pipeline = Pipeline(stages=indexers + encoders)
data = pipeline.fit(data).transform(data)

# Drop the original and indexed columns, keeping only encoded columns
data = data.drop(*categorical_columns)
for col in categorical_columns:
    data = data.drop(col+"_indexed")

# %% [markdown]
# ## Fixing Numerical Columns (Conversion to Double)

# %%
data = data.withColumn("usd_pledged_real", data["usd_pledged_real"].cast(DoubleType()))
data = data.withColumn("usd_goal_real", data["usd_goal_real"].cast(DoubleType()))

# %% [markdown]
# ## Dropping Null Values

# %%
data = data.dropna()

# %% [markdown]
# ## Defining Feature Columns and Assembling Vector from Label + Features

# %%
feature_columns = [col for col in data.columns if col != "label"]

assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
data = assembler.transform(data)

# %% [markdown]
# ## Selecting the Relevant Columns for Modeling

# %%
data = data.select("features", "label")

# %% [markdown]
# ## Splitting Data into Training and Testing Sets

# %%
train_data, test_data = data.randomSplit([0.8, 0.2], seed=1234)

# %% [markdown]
# ## Model 1: Logistic Regression

# %%
lr = LogisticRegression(featuresCol="features", labelCol="label")
lr_model = lr.fit(train_data)
lr_predictions = lr_model.transform(test_data)
# Out:
# 24/05/20 20:41:54 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:08 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/05/20 20:42:10 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:20 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:25 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:30 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:36 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:42 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:47 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:53 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:42:57 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:02 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:07 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:12 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:17 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:23 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:27 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:32 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:37 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:42 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:46 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:52 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:43:58 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:03 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:07 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:12 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:17 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:22 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:28 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:32 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:37 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:41 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:47 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:51 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:44:56 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:02 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:06 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:11 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:16 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:21 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:26 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:30 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:36 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:41 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:46 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:51 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:45:56 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:01 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:05 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:11 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:15 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:20 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:25 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:30 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:35 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:41 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:45 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:50 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:46:55 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:00 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:05 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:10 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:14 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:20 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:24 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:30 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:35 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:39 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:45 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:49 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:54 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:47:59 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:04 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:08 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:14 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:18 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:24 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:28 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:33 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:38 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:44 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:48 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:53 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:48:58 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:03 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:07 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:13 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:18 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:23 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:27 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:32 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:37 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:42 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:46 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:51 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:49:56 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:01 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:06 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:11 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:16 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:21 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:26 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:31 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:36 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:41 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:45 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:51 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:50:56 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:51:01 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB

# %% [markdown]
# ## Model 2: Decision Tree Classifier

# %%
dt = DecisionTreeClassifier(featuresCol="features", labelCol="label")
dt_model = dt.fit(train_data)
dt_predictions = dt_model.transform(test_data)
# Out:
# 24/05/20 20:51:15 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:51:29 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:51:34 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:51:43 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 20:51:50 WARN DAGScheduler: Broadcasting large task binary with size 6.7 MiB
# 24/05/20 20:51:53 WARN DAGScheduler: Broadcasting large task binary with size 66.5 MiB
# 24/05/20 20:52:20 WARN MemoryStore: Not enough space to cache rdd_200_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 20:52:20 WARN BlockManager: Persisting block rdd_200_1 to disk instead.
# 24/05/20 20:52:20 WARN MemoryStore: Not enough space to cache rdd_200_2 in memory! (computed 3.0 GiB so far)
# 24/05/20 20:52:20 WARN BlockManager: Persisting block rdd_200_2 to disk instead.
# 24/05/20 20:52:20 WARN MemoryStore: Not enough space to cache rdd_200_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 20:52:20 WARN BlockManager: Persisting block rdd_200_0 to disk instead.
# 24/05/20 20:53:03 WARN MemoryStore: Not enough space to cache rdd_200_3 in memory! (computed 10.5 GiB so far)
# 24/05/20 20:53:03 WARN BlockManager: Persisting block rdd_200_3 to disk instead.
# 24/05/20 21:02:28 WARN MemoryStore: Not enough space to cache rdd_200_3 in memory! (computed 10.5 GiB so far)
# 24/05/20 21:06:35 WARN MemoryStore: Not enough space to cache rdd_200_0 in memory! (computed 4.7 GiB so far)
# 24/05/20 21:06:36 WARN MemoryStore: Not enough space to cache rdd_200_2 in memory! (computed 4.7 GiB so far)
# 24/05/20 21:06:40 WARN MemoryStore: Not enough space to cache rdd_200_1 in memory! (computed 4.7 GiB so far)
# 24/05/20 21:15:44 WARN DAGScheduler: Broadcasting large task binary with size 66.5 MiB
# 24/05/20 21:15:57 WARN MemoryStore: Not enough space to cache rdd_200_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:15:57 WARN MemoryStore: Not enough space to cache rdd_200_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:15:57 WARN MemoryStore: Not enough space to cache rdd_200_2 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:16:02 WARN MemoryStore: Not enough space to cache rdd_200_3 in memory! (computed 4.7 GiB so far)
# 24/05/20 21:25:10 WARN DAGScheduler: Broadcasting large task binary with size 66.5 MiB
# 24/05/20 21:25:21 WARN MemoryStore: Not enough space to cache rdd_200_3 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:25:21 WARN MemoryStore: Not enough space to cache rdd_200_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:25:22 WARN MemoryStore: Not enough space to cache rdd_200_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:25:26 WARN MemoryStore: Not enough space to cache rdd_200_2 in memory! (computed 4.7 GiB so far)
# 24/05/20 21:34:34 WARN DAGScheduler: Broadcasting large task binary with size 66.5 MiB
# 24/05/20 21:34:45 WARN MemoryStore: Not enough space to cache rdd_200_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:34:45 WARN MemoryStore: Not enough space to cache rdd_200_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:34:46 WARN MemoryStore: Not enough space to cache rdd_200_2 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:34:50 WARN MemoryStore: Not enough space to cache rdd_200_3 in memory! (computed 4.7 GiB so far)
# 24/05/20 21:41:42 WARN DAGScheduler: Broadcasting large task binary with size 66.5 MiB
# 24/05/20 21:41:57 WARN MemoryStore: Not enough space to cache rdd_200_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:41:58 WARN MemoryStore: Not enough space to cache rdd_200_2 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:41:58 WARN MemoryStore: Not enough space to cache rdd_200_3 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:42:03 WARN MemoryStore: Not enough space to cache rdd_200_0 in memory! (computed 4.7 GiB so far)

# %% [markdown]
# ## Model 3: Random Forest Classifier

# %%
rf = RandomForestClassifier(featuresCol="features", labelCol="label")
rf_model = rf.fit(train_data)
rf_predictions = rf_model.transform(test_data)
# Out:
# 24/05/20 21:48:43 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 21:48:55 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 21:48:59 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 21:49:08 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# 24/05/20 21:49:13 WARN DAGScheduler: Broadcasting large task binary with size 6.7 MiB
# 24/05/20 21:49:17 WARN DAGScheduler: Broadcasting large task binary with size 66.5 MiB
# 24/05/20 21:49:39 WARN MemoryStore: Not enough space to cache rdd_244_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:49:39 WARN BlockManager: Persisting block rdd_244_0 to disk instead.
# 24/05/20 21:49:39 WARN MemoryStore: Not enough space to cache rdd_244_2 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:49:39 WARN BlockManager: Persisting block rdd_244_2 to disk instead.
# 24/05/20 21:49:39 WARN MemoryStore: Not enough space to cache rdd_244_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 21:49:39 WARN BlockManager: Persisting block rdd_244_1 to disk instead.
# 24/05/20 21:50:19 WARN MemoryStore: Not enough space to cache rdd_244_3 in memory! (computed 10.5 GiB so far)
# 24/05/20 21:50:19 WARN BlockManager: Persisting block rdd_244_3 to disk instead.
# 24/05/20 21:59:26 WARN MemoryStore: Not enough space to cache rdd_244_3 in memory! (computed 10.5 GiB so far)
# 24/05/20 22:03:25 WARN MemoryStore: Not enough space to cache rdd_244_2 in memory! (computed 2024.9 MiB so far)
# 24/05/20 22:03:28 WARN MemoryStore: Not enough space to cache rdd_244_1 in memory! (computed 4.7 GiB so far)
# 24/05/20 22:03:30 WARN MemoryStore: Not enough space to cache rdd_244_0 in memory! (computed 7.0 GiB so far)
# 24/05/20 22:08:20 WARN DAGScheduler: Broadcasting large task binary with size 66.5 MiB
# 24/05/20 22:08:33 WARN MemoryStore: Not enough space to cache rdd_244_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:08:33 WARN MemoryStore: Not enough space to cache rdd_244_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:08:33 WARN MemoryStore: Not enough space to cache rdd_244_2 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:08:53 WARN MemoryStore: Not enough space to cache rdd_244_3 in memory! (computed 10.5 GiB so far)
# 24/05/20 22:14:07 WARN DAGScheduler: Broadcasting large task binary with size 66.6 MiB
# 24/05/20 22:14:22 WARN MemoryStore: Not enough space to cache rdd_244_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:14:22 WARN MemoryStore: Not enough space to cache rdd_244_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:14:22 WARN MemoryStore: Not enough space to cache rdd_244_2 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:14:40 WARN MemoryStore: Not enough space to cache rdd_244_3 in memory! (computed 10.5 GiB so far)
# 24/05/20 22:19:44 WARN DAGScheduler: Broadcasting large task binary with size 66.6 MiB
# 24/05/20 22:19:57 WARN MemoryStore: Not enough space to cache rdd_244_3 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:19:57 WARN MemoryStore: Not enough space to cache rdd_244_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:19:58 WARN MemoryStore: Not enough space to cache rdd_244_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:20:17 WARN MemoryStore: Not enough space to cache rdd_244_2 in memory! (computed 10.5 GiB so far)
# 24/05/20 22:25:19 WARN DAGScheduler: Broadcasting large task binary with size 66.6 MiB
# 24/05/20 22:25:33 WARN MemoryStore: Not enough space to cache rdd_244_3 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:25:33 WARN MemoryStore: Not enough space to cache rdd_244_0 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:25:33 WARN MemoryStore: Not enough space to cache rdd_244_1 in memory! (computed 3.0 GiB so far)
# 24/05/20 22:25:54 WARN MemoryStore: Not enough space to cache rdd_244_2 in memory! (computed 10.5 GiB so far)

# %% [markdown]
# ## Initialising an Evaluator and Setting Accuracy as the Main Evaluation Metric

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")

# %% [markdown]
# ## Calculating Accuracies for the 3 Models Above

# %%
lr_accuracy = evaluator.evaluate(lr_predictions)
print(f"Logistic Regression Accuracy: {lr_accuracy}")

dt_accuracy = evaluator.evaluate(dt_predictions)
print(f"Decision Tree Accuracy: {dt_accuracy}")

rf_accuracy = evaluator.evaluate(rf_predictions)
print(f"Random Forest Accuracy: {rf_accuracy}")
# Out:
# 24/05/20 22:32:37 WARN DAGScheduler: Broadcasting large task binary with size 59.4 MiB
# Logistic Regression Accuracy: 0.6439538438645618
# 24/05/20 22:32:47 WARN DAGScheduler: Broadcasting large task binary with size 56.6 MiB
# Decision Tree Accuracy: 0.9757179768137115
# 24/05/20 22:32:57 WARN DAGScheduler: Broadcasting large task binary with size 56.7 MiB
# [Stage 157:==============>                                          (1 + 3) / 4]
# Random Forest Accuracy: 0.6385292804675134
